# %% [markdown]
# Import all libraries needed

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# Scrap the wikipedia page and remove all not assigned boroughs and assign all not assigned nehiborhoods to the name of its respective borough
# Create a dataframe for the toronto downtown area for kmeans cluster

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M", header=0)[0]


df = df[df.Borough != "Not assigned"]
toronto_cluster =df[df.Borough == "Downtown Toronto"]



df["Neighbourhood"].replace("Not assigned","Queen's Park", inplace=True)


#for i in df['Neighbourhood']: 
  
  #if i == "Not assigned":
   #  i="Not_assigned"

# %% [markdown]
# Group all neighbourhoods with the same postal code

# %%
comma = lambda a: " , ".join(a) 
#df.groupby(by='Postcode').agg( { 'Borough':comma,'Neighbourhood':comma}).reset_index()
df = df.groupby(['Postcode','Borough'], sort = False).agg(comma)

# %% [markdown]
# Calculate the shape of the dataframe

# %%
df.shape
# Out:
# (103, 1)

# %%
df1=pd.read_csv("http://cocl.us/Geospatial_data")
df1 = df1.rename(columns={'Postal Code': 'Postcode'})

# %% [markdown]
# Assign the each postal code with its respective latitude and longitude

# %%
df2 = df.join(df1.set_index('Postcode'), on='Postcode')

df2.head()
# Out:
#                                                Neighbourhood   Latitude  \
# Postcode Borough
# M3A      North York                                Parkwoods  43.753259
# M4A      North York                         Victoria Village  43.725882
# M5A      Downtown Toronto         Harbourfront , Regent Park  43.654260
# M6A      North York        Lawrence Heights , Lawrence Manor  43.718518
# M7A      Queen's Park                           Queen's Park  43.662301
#
#                            Longitude
# Postcode Borough
# M3A      North York       -79.329656
# M4A      North York       -79.315572
# M5A      Downtown Toronto -79.360636
# M6A      North York       -79.464763
# M7A      Queen's Park     -79.389494

# %% [markdown]
# cluster toronto neighborhoods with a kcluster factor of 5.

# %%
#df2 = pd.merge(df, df1, on='Postcode')
#toronto_cluster 
toronto_cluster_merge = pd.merge(toronto_cluster,df1, on='Postcode')
toronto_cluster_merge = toronto_cluster_merge[toronto_cluster_merge.Neighbourhood != "St. James Town"]
kclusters = 5

toronto_cluster_loc = toronto_cluster_merge[["Latitude", "Longitude"]]
#toronto_cluster_loc
#toronto_cluster_loc = toronto_cluster.drop('Neighbourhood', 1)
#toronto_cluster_loc = toronto_cluster_loc[:-2]
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_cluster_loc)


kmeans.labels_.shape
# Out:
# (35,)

# %%
columns = ['Neighbourhood']
neighborhoods_venues_sorted = pd.DataFrame(columns=['Neighbourhood'])
#neighborhoods_venues_sorted  
neighborhoods_venues_sorted['Neighbourhood'] = toronto_cluster_merge['Neighbourhood']


neighborhoods_venues_sorted.drop_duplicates(keep=False,inplace=True) 
neighborhoods_venues_sorted.reset_index()
neighborhoods_venues_sorted.shape
# Out:
# (35, 1)

# %% [markdown]
# Add the cluster labels to the toronto area dataframe

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
toronto_cluster_merge = toronto_cluster_merge.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

toronto_cluster_merge # check the last columns!
# Out:
#    Postcode           Borough                    Neighbourhood   Latitude  \
# 0       M5A  Downtown Toronto                     Harbourfront  43.654260
# 1       M5A  Downtown Toronto                      Regent Park  43.654260
# 2       M5B  Downtown Toronto                          Ryerson  43.657162
# 3       M5B  Downtown Toronto                  Garden District  43.657162
# 5       M5E  Downtown Toronto                      Berczy Park  43.644771
# 6       M5G  Downtown Toronto               Central Bay Street  43.657952
# 7       M6G  Downtown Toronto                         Christie  43.669542
# 8       M5H  Downtown Toronto                         Adelaide  43.650571
# 9       M5H  Downtown Toronto                             King  43.650571
# 10      M5H  Downtown Toronto                         Richmond  43.650571
# 11      M5J  Downtown Toronto                Harbourfront East  43.640816
# 12      M5J  Downtown Toronto                  Toronto Islands  43.640816
# 13      M5J  Downtown Toronto                    Union Station  43.640816
# 14      M5K  Downtown Toronto                  Design Exchange  43.647177
# 15      M5K  Downtown Toronto          Toronto Dominion Centre  43.647177
# 16      M5L  Downtown Toronto                   Commerce Court  43.648198
# 17      M5L  Downtown Toronto                   Victoria Hotel  43.648198
# 18      M5S  Downtown Toronto                          Harbord  43.662696
# 19      M5S  Downtown Toronto            University of Toronto  43.662696
# 20      M5T  Downtown Toronto                        Chinatown  43.653206
# 21      M5T  Downtown Toronto                      Grange Park  43.653206
# 22      M5T  Downtown Toronto                Kensington Market  43.653206
# 23      M5V  Downtown Toronto                         CN Tower  43.628947
# 24      M5V  Downtown Toronto                    Bathurst Quay  43.628947
# 25      M5V  Downtown Toronto                   Island airport  43.628947
# 26      M5V  Downtown Toronto                Harbourfront West  43.628947
# 27      M5V  Downtown Toronto                 King and Spadina  43.628947
# 28      M5V  Downtown Toronto                    Railway Lands  43.628947
# 29      M5V  Downtown Toronto                    South Niagara  43.628947
# 30      M4W  Downtown Toronto                         Rosedale  43.679563
# 31      M5W  Downtown Toronto  Stn A PO Boxes 25 The Esplanade  43.646435
# 32      M4X  Downtown Toronto                      Cabbagetown  43.667967
# 34      M5X  Downtown Toronto             First Canadian Place  43.648429
# 35      M5X  Downtown Toronto                 Underground city  43.648429
# 36      M4Y  Downtown Toronto             Church and Wellesley  43.665860
#
#     Longitude  Cluster Labels
# 0  -79.360636               0
# 1  -79.360636               0
# 2  -79.378937               4
# 3  -79.378937               4
# 5  -79.373306               4
# 6  -79.387383               4
# 7  -79.422564               3
# 8  -79.384568               4
# 9  -79.384568               4
# 10 -79.384568               4
# 11 -79.381752               4
# 12 -79.381752               4
# 13 -79.381752               4
# 14 -79.381576               4
# 15 -79.381576               4
# 16 -79.379817               4
# 17 -79.379817               4
# 18 -79.400049               3
# 19 -79.400049               3
# 20 -79.400049               3
# 21 -79.400049               3
# 22 -79.400049               3
# 23 -79.394420               2
# 24 -79.394420               2
# 25 -79.394420               2
# 26 -79.394420               2
# 27 -79.394420               2
# 28 -79.394420               2
# 29 -79.394420               2
# 30 -79.377529               1
# 31 -79.374846               4
# 32 -79.367675               1
# 34 -79.382280               4
# 35 -79.382280               4
# 36 -79.383160               1

# %% [markdown]
# Create a map of the toronto area which shows the clusters around the downtown area.

# %%
map = folium.Map(location=[43.6532, -79.3832], zoom_start=12)

x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

markers_colors = []
for lat, lon, poi, cluster in zip(toronto_cluster_merge['Latitude'], toronto_cluster_merge['Longitude'], toronto_cluster_merge['Neighbourhood'], toronto_cluster_merge['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster-1)],
        fill=True,
        fill_color=rainbow[int(cluster)],
        fill_opacity=0.7).add_to(map)
       
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
